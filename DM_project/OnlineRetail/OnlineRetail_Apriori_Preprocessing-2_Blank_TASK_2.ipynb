# %% [markdown]
# <a href='https://www.darshan.ac.in/'>
#   <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/>
# </a>
#
# <center>
#   <h1><b>Data Mining</b></h1>
#   <h1><b>🧺 Online Retail Dataset (Apriori Preprocessing) - TASK 2</b></h1>
# </center>
#
# ---
#
# ### **Name:** Harmik Rathod
# ### **Enrollment No:** 24010101680
# ### **Subject Code:** 2301CS503
# ### **Course:** B.Tech in Computer Science & Engineering
# ### **Semester:** 5
# ### **Division:** B
#
# ### **Instructor:** Prof. Jayesh Vagadiya
#
# ---

# %% [markdown]
# **Dataset**: https://www.kaggle.com/datasets/vijayuv/onlineretail

# %% [markdown]
# # Step 1: Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('OnlineRetail.csv', encoding='ISO-8859-1')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 2: Drop Missing Invoices or Descriptions

# %%
drop_with_dropna=df.dropna(subset=["InvoiceNo","Description"])

# %%
drop_with_dropna
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 3: Remove Canceled Invoices <BR> Start with letter 'c'

# %%
remove_canceled_invoice=df[~df['InvoiceNo'].str.lower().str.startswith('c')]

# %%
remove_canceled_invoice
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 4: Keep Only Positive Quantities

# %%
positive_quantites=df[df['Quantity']>0]

# %%
positive_quantites
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# # Step 5: Standardize Item Descriptions | Lower case and remove space

# %%
df['Description'] = df['Description'].str.lower().str.replace(' ', '', regex=False)

# %% [markdown]
# ### df

# %% [markdown]
# # Step 6: Filter for a Single Country (e.g., United Kingdom)

# %%
single_country=df[df['Country']=='United Kingdom']

# %%
single_country
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541889    581585     22466      fairytalecottagenightlight        12
# 541890    581586     22061  largecakestandhangingstrawbery         8
# 541891    581586     23275      setof3hangingowlsolliebeak        24
# 541892    581586     21217       redretrospotroundcaketins        24
# 541893    581586     20685             doormatredretrospot        10
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %% [markdown]
# # Step 7: Remove Duplicates

# %%
remove_duplicate=df.drop_duplicates()

# %%
remove_duplicate
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541904    581587     22613         packof20spaceboynapkins        12
# 541905    581587     22899        children'saprondollygirl         6
# 541906    581587     23254       childrenscutlerydollygirl         4
# 541907    581587     23255    childrenscutlerycircusparade         4
# 541908    581587     22138        bakingset9pieceretrospot         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# ...

# %% [markdown]
# # Step 8: Add TotalPrice column , TotalPrice = Quantity *  UnitPrice

# %%
df['TotalPrice']=df['Quantity']*df['UnitPrice']

# %%
df
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 0         536365    85123A  whitehangingheartt-lightholder         6
# 1         536365     71053               whitemetallantern         6
# 2         536365    84406B      creamcupidheartscoathanger         8
# 3         536365    84029G  knittedunionflaghotwaterbottle         6
# 4         536365    84029E      redwoollyhottiewhiteheart.         6
# ...          ...       ...                             ...       ...
# 541904    581587     22613         packof20spaceboynapkins        12
# 541905    581587     22899        children'saprondollygirl         6
# 541906    581587     23254       childrenscutlerydollygirl         4
# 541907    581587     23255    childrenscutlerycircusparade         4
# 541908    581587     22138        bakingset9pieceretrospot         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %% [markdown]
# # Step 9 : Check for Top 10 Selling Products

# %%
top_10_products_df = (df.groupby('Description')['Quantity'].sum().reset_index().sort_values(by='Quantity', ascending=False).head(10))
print(top_10_products_df)
# Out:
#                          Description  Quantity
# 4070    worldwar2glidersasstddesigns     53847
# 1880            jumbobagredretrospot     47363
# 242       assortedcolourbirdornament     36381
# 2764                   popcornholder     36334
# 2426      packof72retrospotcakecases     36039
# 3981  whitehangingheartt-lightholder     35317
# 2827                rabbitnightlight     30680
# 2182             minipaintsetvintage     26437
# 2392           packof12londontissues     26315
# 2413    packof60pinkpaisleycakecases     24753

# %% [markdown]
# # Step 10 : Identify Most Active Customers

# %%
top_customers_qty = (df.groupby('CustomerID')['Quantity'].sum().sort_values(ascending=False).head(10))
print(top_customers_qty)
# Out:
# CustomerID
# 14646.0    196719
# 12415.0     77242
# 14911.0     77180
# 17450.0     69029
# 18102.0     64122
# 17511.0     63012
# 13694.0     61803
# 14298.0     58021
# 14156.0     57025
# 16684.0     49390
# Name: Quantity, dtype: int64

# %% [markdown]
# # Step 11: Time-Based Analysis | Convert InvoiceDate to datetime and check popular months/hours.

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Month'] = df['InvoiceDate'].dt.month
monthly_sales = df.groupby('Month')['TotalPrice'].sum()
plt.bar(monthly_sales.index, monthly_sales.values, color='steelblue')
plt.title('Monthly Sales Volume')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Step 12: Convert to Basket Format

# %% [markdown]
# Example
# <table border="1">
#     <thead>
#         <tr>
#             <th>Transaction</th>
#             <th>Milk</th>
#             <th>Bread</th>
#             <th>Butter</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr><td>T1</td><td>1</td><td>1</td><td>1</td></tr>
#         <tr><td>T2</td><td>0</td><td>1</td><td>1</td></tr>
#         <tr><td>T3</td><td>1</td><td>0</td><td>0</td></tr>
#         <tr><td>T4</td><td>1</td><td>1</td><td>0</td></tr>
#         <tr><td>T5</td><td>0</td><td>1</td><td>1</td></tr>
#     </tbody>
# </table>

# %%
basket = df.groupby(['InvoiceNo', 'Description'])['Quantity'].sum().unstack().fillna(0)

# %%
basket = basket.gt(0).astype(int)

# %%
basketz
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                    0                               0
# 536366                                    0                               0
# 536367                                    0                               0
# 536368                                    0                               0
# 536369                                    0                               0
# ...                                     ...                             ...
# C581484                                   0                               0
# C581490                                   0                               0
# C581499                                   0                               0
# C581568                                   0                               0
# C581569                                   0                               0
#
# ...

# %% [markdown]
# # Step:13 : Save Basket Format into CSV file

# %%
basket.to_csv('BasketFormat.csv')
